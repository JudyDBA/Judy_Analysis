# %% [markdown]
# # 더본 코리아 브랜드 및 지역별 매장 분석(백주부)

# %% [markdown]
# ### 추숙 2016.01.31

# %% [markdown]
# <http://www.theborn.co.kr/tb/store_domestic.asp>

# %% [markdown]
# ![백주부](http://outstanding.kr/wp-content/uploads/2016/01/%EC%9E%90%EB%A3%8C45.png)

# %% [markdown]
# ---

# %%
# %pylab inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

style.use('ggplot')
rcParams['font.family'] = 'HYGothic-Extra'
rcParams['font.size'] = 10
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
## 더본 코리아 매장 게시글 크롤링 모듈
import store as st

# %%
bk_store = st.LoadShop()

# %%
df = pd.DataFrame(bk_store)
##df.head(5)

# %% [markdown]
# ## 총 매장수

# %%
df['Seats_num'].count()
# Out:
# 1100

# %% [markdown]
# ## 총 브랜드수

# %%
## 브랜드별 매장수
brand_gb = df.groupby('brand')

# %%
len(brand_gb.groups)
# Out:
# 33

# %%
brand = df['brand'].value_counts().copy()

# %% [markdown]
# ## Top10 브랜드별 매장수

# %%
## 매장수 top10 브랜드별 매장수
## color : http://matplotlib.org/api/colors_api.html
brand[:10].plot(kind='bar', color=['r', 'g', 'b', 'c', 'k', 'm', 'y', 'w', 'm', '#eeefff'])

# %%
brand[:10].plot(kind='pie', autopct='%.2f', fontsize=10)
